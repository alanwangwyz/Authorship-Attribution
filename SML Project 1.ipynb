# %% [markdown]
# # COMP90051 Authorship Attribution
# ----------
#
# `1.` [Loading Data](#loading)
#
#     1.1 Loading Packages
#     1.2 Loading Train, Test

# %% [markdown]
# <a class="anchor" id="loading"></a>
# # Loading Data

# %%
import re, pickle, os, string
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import numpy as np 
import pandas as pd 
import nltk
import string
import spacy
from profanity import profanity
from nltk.corpus import stopwords
from spacy.util import compile_prefix_regex, compile_infix_regex, compile_suffix_regex
from spacy.tokenizer import Tokenizer
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# %%
train_data = None
test_data = None

def load_data():
    global train_data, test_data
    train_data = pd.read_csv('train_tweets.txt', delimiter="\t", header=None)
    test_data = pd.read_csv('test_tweets_unlabeled.txt', delimiter="\t", header = None)

load_data()
train_data.columns = ['Author', 'Tweet']
print(train_data)
# Out:
#         Author                                              Tweet
# 0         8746     @handle Let's try and catch up live next week!
# 1         8746  Going to watch Grey's on the big screen - Thur...
# 2         8746  @handle My pleasure Patrick....hope you are well!
# 3         8746  @handle Hi there! Been traveling a lot and lot...
# 4         8746  RT @handle Looking to Drink Clean & Go Green? ...
# 5         8746  RT @handle: Ft. Hood officials confirm the 2 o...
# 6         8746  RT @handle: Mickey Mouse is Getting a Make Ove...
# 7         8746           @handle How did u get the invite Justin?
# 8         8746  @handle I think I am still a good friend of he...
# 9         8746  @handle I remember! I am fine - how are u? Wha...
# 10        8746     @handle That's great - good for the coach!!!!!
# 11        8746  @handle I don't want to picture u sitting on i...
# 12        8746  @handle D- Thanks for the RTs....are you going...
# 13        8746           @handle Grrr....you must be going crazy!
# 14        8746  @handle Hi there - just catching up from my tr...
# 15        8746  RT @handle: If you're looking for some great l...
# 16        8746  RT @handle: Retailers who aren’t engaging cust...
# 17        8746  RT @handle: Director of Global Brand Marketing...
# 18        8746  Still in car....want to jump out....45 minutes...
# 19        8746  RT @handle: "Only surround yourself with peopl...
# 20        8746  @handle wish I could but 24/7 w stu's family t...
# 21        8746  RT @handle: Help us help MusiCares! Vote for C...
# 22        8746                     @handle yum!!!! Save me some!!
# 23        8746  RT @handle: Gratitude is the sign of noble sou...
# 24        8746           @handle I don't think I know what it is!
# 25        8746  RT @handle: @handle Just found you via @handle...
# 26        8746  RT @handle: RT @handle: Travelling for the Hol...
# 27        8746       Just entering ohio - special hi to @handle!!
# 28        8746  @handle well we agree on one food thing friend...
# 29        8746                                @handle only 1!!!!!
# ...        ...                                                ...
# 328165    1319                                            @handle
# 328166    1319  @handle Please add me to the #awsms09 afterpar...
# 328167    1319  @handle great party last night...met some tale...
# 328168    1319  Alta Phoenix Lofts #1 Phoenix!!!!! Congrats to...
# 328169    9235                You manage things; you lead people.
# 328170    9235  Not to know is bad; not to wish to know is worse.
# 328171    9235  That there should one man die ignorant who had...
# 328172    9235                       Will is character in action.
# 328173    9235     What the mind dwells upon, the body acts upon.
# 328174    9235      Success as I see it, is a result, not a goal.
# 328175    9235  All generalizations are false, including this ...
# 328176    9235  It is the province of knowledge to speak and i...
# 328177    9235  A leader, once convinced that a particular cou...
# 328178    9235  You can not make excuses and money at the same...
# 328179    4357  Henry Brothers Electronics, Inc. to Participat...
# 328180    4357  TechInsights' ESC UK Event Showcases Leading C...
# 328181    4357  DEMOfall 09 Announces Lineup of Emerging Techn...
# 328182    4357  AFP Hosts Symposium on Essentials for Doing Bu...
# 328183    4357  AlertEnterprise Wins ASIS Accolades 2009 Secur...
# 328184    4357  Andrews International Introduces New Methodolo...
# 328185    4357  Innovation Strong Despite Recession: Human Res...
# 328186    4357  VideoIQ and Milestone Systems Partner to Deliv...
# 328187    4357  Phoenix Technologies to Showcase Cutting Edge ...
# 328188    4357  AnyDATA's APT-210 Tracking Device Measures Att...
# 328189    4357  Samplify Systems Announces Distribution Agreem...
# 328190    4357  Steelbox Demonstrates Open Video Framework wit...
# 328191    4357  Small Businesses Rely on Sage to Help Them Rid...
# 328192    4357  TimeSight Systems™ Announces Next-Generation P...
# 328193    4357  Diebold Makes Its Leading Monitoring Solutions...
# 328194    4357  GVI Security Solutions to Introduce AutoIP™ VM...
#
# [328195 rows x 2 columns]

# %%
def load_pickle(filepath):
    documents_f = open(filepath, 'rb')
    file = pickle.load(documents_f)
    documents_f.close()
    
    return file

def save_pickle(data, filepath):
    save_documents = open(filepath, 'wb')
    pickle.dump(data, save_documents)
    save_documents.close()

# %%
# def custom_tokenizer(nlp):
#     infix_re = re.compile(r'''[.\?\:\;\...\‘\’\`\“\”\"\'~]''')
#     prefix_re = compile_prefix_regex(nlp.Defaults.prefixes)
#     suffix_re = compile_suffix_regex(nlp.Defaults.suffixes)

#     return Tokenizer(nlp.vocab, prefix_search=prefix_re.search,
#                                 suffix_search=suffix_re.search,
#                                 infix_finditer=infix_re.finditer,
#                                 token_match=None)
# spacy_nlp = spacy.load("en")
# spacy_nlp.tokenizer = custom_tokenizer(spacy_nlp)
nlp1 = spacy.load('en_core_web_lg')

stp = [word for word in list(stopwords.words('english') + [ "'s", "'m", "ca"])
        if word not in ["no", "not"] and word.rfind("n't") == -1]

class PreProcessor(object):
    '''Pre-processor which cleans text, lemmatises, removes stop words and punctuation, 
    returns df of processed text.'''

    def __init__(self):
        self._stopWordList = stp
        self._punct_removal = list(string.punctuation)
        self.sid = SentimentIntensityAnalyzer()

#     def _tokenize_text(self, sample):
#         '''tokenises sentences in order to lemmatise, remove stop words and punctuation, 
#         returns string of processed text'''

#         # get tokens using spacy
#         tokens = spacy_nlp(sample)

#         # lemmatising tokens
#         tokens = [t.lemma_.strip()
#                   if t.lemma_ != "-PRON-"
#                   else t.lower_
#                   for t in tokens]

#         # stopword and punctuation removal
#         tokens = [t.lower() for t in tokens
#                   if (t not in self._stopWordList and t not in self._punct_removal)]

#         processed_text = " ".join(tokens)
#         return processed_text
    
    def remove_url(self, text):
        result = re.sub(r"http\S+", "", text)
        return result
    
    def check_url(self, text):
        url = re.findall('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', text) 
        if len(url) != 0:
            return True
        return False
    
    def unique_words(self, words):
        word_count = len(words)
        unique_count = len(set(words))
        if word_count!=0:
            return unique_count / word_count
        return 0
    
    def mention(self, text):
        return set([re.sub(r"(\W+)$", "", j) for j in set([i for i in text.split() if i.startswith("@")])])
    
    def retweet(self, text):
        rt = 'rt'
        if rt in text:
            return True
        return False
    
    def hashtag(self, text):
        return set([re.sub(r"(\W+)$", "", j) for j in set([i for i in text.split() if i.startswith("#")])])
    
    def extract_emojis(self, text):
        happy = [':-)', ':-D', ':)', ':o)', ':]', ':3', ':c)', ':>', '=]', '8)', '=)', ':}', ':^']
        sad = [':-(', ':(', ':\'-(', ':\'(', ':\'-)' ':\')', ':-|', ':-', ':{', ':[', ':\\', ':*',':&', ':<']
        for each in happy:
            if each in text:
                return 'Happy'
                break
                   
        for each in sad:
            if each in text:
                return 'Sad'
                break
        return ''
    
    def profanity_analysis(self, content):
        contain_profanity=profanity.contains_profanity(content)
        return contain_profanity
    
    def location_finder(self, text):
        doc = nlp1(text)
        for ent in doc.ents:
            if ent.label_ == 'GPE':
                 return ent.text
                 break
 
    def transform_text(self, data):
        
        '''applies the clean and tokenise methods to the texts, 
        encodes the target variable to numerical. 
        Option to set pickle to True to save clean df'''
        no_punct_translator=str.maketrans('','',string.punctuation)
        
        data['words'] = data['Tweet'].apply(lambda row: self.remove_url(str(row))).apply(lambda t: nltk.word_tokenize(t.translate(no_punct_translator).lower()))
        data['URL'] = data['Tweet'].apply(lambda row: self.check_url(str(row)))
        data['word_count'] = data['words'].apply(lambda words: len(words))
        data['sentence_length'] = data['words'].apply(lambda w: sum(map(len, w)))
        data['text_length'] = data['Tweet'].apply(lambda t: len(str(t)))
        data['sentiment'] = data['Tweet'].apply(lambda t: self.sid.polarity_scores(t)['compound'])
        data['punctuation_per_tweet'] = data['Tweet'].apply(lambda t: len(list(filter(lambda c: c in t, string.punctuation)))) / data['text_length']
        data['unique_ratio'] = data['words'].apply(lambda row: self.unique_words(row))
        data['avg_word_length'] = data['words'].apply(lambda words: sum(map(len, words)) / len(words) if len(words)!=0 else 0)
        data['mention'] = data['Tweet'].apply(lambda row: self.mention(str(row)))
        data['Retweet'] = data['words'].apply(lambda row: self.retweet(str(row)))
        data['Hashtag'] = data['Tweet'].apply(lambda row: self.hashtag(str(row)))
        data['emojis'] = data['Tweet'].apply(lambda row: self.extract_emojis(str(row)))
        data['profanity'] = data['words'].apply(lambda row: self.profanity_analysis(str(row)))
        return data
    
    def transform_text1(self, data):
        data['location'] = data['Tweet'].apply(lambda row: self.location_finder(str(row)))
        return data

# %%
train_data = load_pickle("train_data.p")

# %%
train_data
# Out:
#         Author                                              Tweet  \
# 0         8746     @handle Let's try and catch up live next week!
# 1         8746  Going to watch Grey's on the big screen - Thur...
# 2         8746  @handle My pleasure Patrick....hope you are well!
# 3         8746  @handle Hi there! Been traveling a lot and lot...
# 4         8746  RT @handle Looking to Drink Clean & Go Green? ...
# 5         8746  RT @handle: Ft. Hood officials confirm the 2 o...
# 6         8746  RT @handle: Mickey Mouse is Getting a Make Ove...
# 7         8746           @handle How did u get the invite Justin?
# 8         8746  @handle I think I am still a good friend of he...
# 9         8746  @handle I remember! I am fine - how are u? Wha...
# 10        8746     @handle That's great - good for the coach!!!!!
# 11        8746  @handle I don't want to picture u sitting on i...
# 12        8746  @handle D- Thanks for the RTs....are you going...
# 13        8746           @handle Grrr....you must be going crazy!
# 14        8746  @handle Hi there - just catching up from my tr...
# 15        8746  RT @handle: If you're looking for some great l...
# 16        8746  RT @handle: Retailers who aren’t engaging cust...
# 17        8746  RT @handle: Director of Global Brand Marketing...
# 18        8746  Still in car....want to jump out....45 minutes...
# 19        8746  RT @handle: "Only surround yourself with peopl...
# 20        8746  @handle wish I could but 24/7 w stu's family t...
# 21        8746  RT @handle: Help us help MusiCares! Vote for C...
# 22        8746                     @handle yum!!!! Save me some!!
# 23        8746  RT @handle: Gratitude is the sign of noble sou...
# 24        8746           @handle I don't think I know what it is!
# 25        8746  RT @handle: @handle Just found you via @handle...
# 26        8746  RT @handle: RT @handle: Travelling for the Hol...
# 27        8746       Just entering ohio - special hi to @handle!!
# 28        8746  @handle well we agree on one food thing friend...
# 29        8746                                @handle only 1!!!!!
# ...        ...                                                ...
# 328165    1319                                            @handle
# 328166    1319  @handle Please add me to the #awsms09 afterpar...
# 328167    1319  @handle great party last night...met some tale...
# 328168    1319  Alta Phoenix Lofts #1 Phoenix!!!!! Congrats to...
# 328169    9235                You manage things; you lead people.
# 328170    9235  Not to know is bad; not to wish to know is worse.
# 328171    9235  That there should one man die ignorant who had...
# 328172    9235                       Will is character in action.
# 328173    9235     What the mind dwells upon, the body acts upon.
# 328174    9235      Success as I see it, is a result, not a goal.
# 328175    9235  All generalizations are false, including this ...
# 328176    9235  It is the province of knowledge to speak and i...
# 328177    9235  A leader, once convinced that a particular cou...
# 328178    9235  You can not make excuses and money at the same...
# 328179    4357  Henry Brothers Electronics, Inc. to Participat...
# 328180    4357  TechInsights' ESC UK Event Showcases Leading C...
# 328181    4357  DEMOfall 09 Announces Lineup of Emerging Techn...
# 328182    4357  AFP Hosts Symposium on Essentials for Doing Bu...
# 328183    4357  AlertEnterprise Wins ASIS Accolades 2009 Secur...
# 328184    4357  Andrews International Introduces New Methodolo...
# 328185    4357  Innovation Strong Despite Recession: Human Res...
# 328186    4357  VideoIQ and Milestone Systems Partner to Deliv...
# 328187    4357  Phoenix Technologies to Showcase Cutting Edge ...
# 328188    4357  AnyDATA's APT-210 Tracking Device Measures Att...
# 328189    4357  Samplify Systems Announces Distribution Agreem...
# 328190    4357  Steelbox Demonstrates Open Video Framework wit...
# 328191    4357  Small Businesses Rely on Sage to Help Them Rid...
# 328192    4357  TimeSight Systems™ Announces Next-Generation P...
# 328193    4357  Diebold Makes Its Leading Monitoring Solutions...
# 328194    4357  GVI Security Solutions to Introduce AutoIP™ VM...
#
#                                                     words    URL  word_count  \
# 0       [handle, lets, try, and, catch, up, live, next...  False           9
# 1       [going, to, watch, greys, on, the, big, screen...  False          10
# 2       [handle, my, pleasure, patrickhope, you, are, ...  False           7
# 3       [handle, hi, there, been, traveling, a, lot, a...  False          25
# 4       [rt, handle, looking, to, drink, clean, go, gr...  False          18
# 5       [rt, handle, ft, hood, officials, confirm, the...  False          17
# 6       [rt, handle, mickey, mouse, is, getting, a, ma...   True          10
# 7         [handle, how, did, u, get, the, invite, justin]  False           8
# 8       [handle, i, think, i, am, still, a, good, frie...  False          12
# 9       [handle, i, remember, i, am, fine, how, are, u...  False          11
# 10          [handle, thats, great, good, for, the, coach]  False           7
# 11      [handle, i, dont, want, to, picture, u, sittin...  False          14
# 12      [handle, d, thanks, for, the, rtsare, you, goi...  False          11
# 13              [handle, grrryou, must, be, going, crazy]  False           6
# 14      [handle, hi, there, just, catching, up, from, ...  False          13
# 15      [rt, handle, if, youre, looking, for, some, gr...   True          15
# 16      [rt, handle, retailers, who, aren, ’, t, engag...   True          17
# 17      [rt, handle, director, of, global, brand, mark...   True          17
# 18      [still, in, carwant, to, jump, out45, minutes,...  False           8
# 19      [rt, handle, only, surround, yourself, with, p...  False          15
# 20      [handle, wish, i, could, but, 247, w, stus, fa...  False          22
# 21      [rt, handle, help, us, help, musicares, vote, ...   True          11
# 22                          [handle, yum, save, me, some]  False           5
# 23      [rt, handle, gratitude, is, the, sign, of, nob...  False          12
# 24        [handle, i, dont, think, i, know, what, it, is]  False           9
# 25      [rt, handle, handle, just, found, you, via, ha...  False          23
# 26      [rt, handle, rt, handle, travelling, for, the,...   True          18
# 27        [just, entering, ohio, special, hi, to, handle]  False           7
# 28      [handle, well, we, agree, on, one, food, thing...  False          19
# 29                                      [handle, only, 1]  False           3
# ...                                                   ...    ...         ...
# 328165                                           [handle]  False           1
# 328166  [handle, please, add, me, to, the, awsms09, af...  False           9
# 328167  [handle, great, party, last, nightmet, some, t...  False           8
# 328168  [alta, phoenix, lofts, 1, phoenix, congrats, t...   True           9
# 328169           [you, manage, things, you, lead, people]  False           6
# 328170  [not, to, know, is, bad, not, to, wish, to, kn...  False          12
# 328171  [that, there, should, one, man, die, ignorant,...  False          17
# 328172                  [will, is, character, in, action]  False           5
# 328173  [what, the, mind, dwells, upon, the, body, act...  False           9
# 328174  [success, as, i, see, it, is, a, result, not, ...  False          11
# 328175  [all, generalizations, are, false, including, ...  False           7
# 328176  [it, is, the, province, of, knowledge, to, spe...  False          17
# 328177  [a, leader, once, convinced, that, a, particul...  False          21
# 328178  [you, can, not, make, excuses, and, money, at,...  False          11
# 328179  [henry, brothers, electronics, inc, to, partic...   True          13
# 328180  [techinsights, esc, uk, event, showcases, lead...   True          15
# 328181  [demofall, 09, announces, lineup, of, emerging...   True          17
# 328182  [afp, hosts, symposium, on, essentials, for, d...   True          11
# 328183  [alertenterprise, wins, asis, accolades, 2009,...   True          10
# 328184  [andrews, international, introduces, new, meth...   True          13
# 328185  [innovation, strong, despite, recession, human...   True          14
# 328186  [videoiq, and, milestone, systems, partner, to...   True          12
# 328187  [phoenix, technologies, to, showcase, cutting,...   True          14
# 328188  [anydatas, apt210, tracking, device, measures,...   True          11
# 328189  [samplify, systems, announces, distribution, a...   True          15
# 328190  [steelbox, demonstrates, open, video, framewor...   True          13
# 328191  [small, businesses, rely, on, sage, to, help, ...   True          13
# 328192  [timesight, systems™, announces, nextgeneratio...   True          12
# 328193  [diebold, makes, its, leading, monitoring, sol...   True          10
# 328194  [gvi, security, solutions, to, introduce, auto...   True          15
#
#         sentence_length  text_length  sentiment  punctuation_per_tweet  \
# 0                    35           46     0.0000               0.065217
# 1                    49           66     0.0000               0.045455
# 2                    37           49     0.7263               0.061224
# 3                   100          132     0.4997               0.030303
# 4                    86          109     0.4019               0.036697
# 5                    86          105    -0.3400               0.028571
# 6                    43           76     0.0000               0.052632
# 7                    31           40     0.1531               0.050000
# 8                    40           55     0.8478               0.054545
# 9                    37           54     0.3510               0.092593
# 10                   31           46     0.8469               0.086957
# 11                   53           77     0.1996               0.051948
# 12                   46           63     0.4404               0.063492
# 13                   29           40    -0.4003               0.075000
# 14                   50           68     0.0000               0.044118
# 15                   63          105     0.6588               0.066667
# 16                   82          117     0.0516               0.034188
# 17                   86          135     0.5423               0.081481
# 18                   35           53     0.0000               0.037736
# 19                   81          101     0.0000               0.049505
# 20                   77          107    -0.3400               0.065421
# 21                   51           86     0.8172               0.058140
# 22                   19           30     0.6562               0.066667
# 23                   57           74     0.7430               0.067568
# 24                   29           40     0.0000               0.075000
# 25                   91          121     0.0000               0.041322
# 26                   76          124     0.4574               0.048387
# 27                   33           44     0.5080               0.068182
# 28                   81          106     0.8777               0.056604
# 29                   11           19     0.0000               0.105263
# ...                 ...          ...        ...                    ...
# 328165                6            7     0.0000               0.142857
# 328166               45           56     0.6369               0.053571
# 328167               46           57     0.8779               0.035088
# 328168               45           79     0.6776               0.063291
# 328169               28           35     0.0000               0.057143
# 328170               36           49    -0.8342               0.040816
# 328171               75           93    -0.8860               0.021505
# 328172               23           28     0.0000               0.035714
# 328173               36           46    -0.0258               0.043478
# 328174               32           45     0.5719               0.044444
# 328175               42           50     0.0000               0.040000
# 328176               68           85     0.7096               0.011765
# 328177               98          125     0.2960               0.016000
# 328178               41           52     0.0000               0.019231
# 328179               80          118     0.0000               0.050847
# 328180               99          135     0.0000               0.037037
# 328181               95          134     0.4404               0.029851
# 328182               61           92     0.0000               0.043478
# 328183               69          101     0.9451               0.049505
# 328184               99          135     0.6369               0.029630
# 328185               97          135     0.8192               0.029630
# 328186               89          122     0.4588               0.040984
# 328187               93          134    -0.1280               0.044776
# 328188               73          108     0.0000               0.055556
# 328189               97          134     0.7003               0.029851
# 328190               99          132     0.1779               0.030303
# 328191               63           96    -0.0258               0.041667
# 328192               93          129     0.4588               0.038760
# 328193               68           99     0.1779               0.040404
# 328194               91          128     0.4767               0.031250
#
#         unique_ratio  avg_word_length
# 0           1.000000         3.888889
# 1           1.000000         4.900000
# 2           1.000000         5.285714
# 3           0.960000         4.000000
# 4           0.888889         4.777778
# 5           1.000000         5.058824
# 6           0.900000         4.300000
# 7           1.000000         3.875000
# 8           0.916667         3.333333
# 9           0.909091         3.363636
# 10          1.000000         4.428571
# 11          0.928571         3.785714
# 12          1.000000         4.181818
# 13          1.000000         4.833333
# 14          1.000000         3.846154
# 15          1.000000         4.200000
# 16          1.000000         4.823529
# 17          1.000000         5.058824
# 18          1.000000         4.375000
# 19          1.000000         5.400000
# 20          1.000000         3.500000
# 21          0.909091         4.636364
# 22          1.000000         3.800000
# 23          0.916667         4.750000
# 24          0.888889         3.222222
# 25          0.869565         3.956522
# 26          0.888889         4.222222
# 27          1.000000         4.714286
# 28          1.000000         4.263158
# 29          1.000000         3.666667
# ...              ...              ...
# 328165      1.000000         6.000000
# 328166      1.000000         5.000000
# 328167      1.000000         5.750000
# 328168      0.888889         5.000000
# 328169      0.833333         4.666667
# 328170      0.583333         3.000000
# 328171      1.000000         4.411765
# 328172      1.000000         4.600000
# 328173      0.777778         4.000000
# 328174      0.909091         2.909091
# 328175      1.000000         6.000000
# 328176      0.705882         4.000000
# 328177      0.904762         4.666667
# 328178      1.000000         3.727273
# 328179      1.000000         6.153846
# 328180      1.000000         6.600000
# 328181      0.941176         5.588235
# 328182      1.000000         5.545455
# 328183      1.000000         6.900000
# 328184      1.000000         7.615385
# 328185      1.000000         6.928571
# 328186      1.000000         7.416667
# 328187      0.928571         6.642857
# 328188      1.000000         6.636364
# 328189      1.000000         6.466667
# 328190      1.000000         7.615385
# 328191      1.000000         4.846154
# 328192      1.000000         7.750000
# 328193      1.000000         6.800000
# 328194      1.000000         6.066667
#
# [328195 rows x 11 columns]

# %%
processor = PreProcessor()
clean_train = processor.transform_text1(train_data)
clean_train.head(60)
# Out:
#     Author                                              Tweet  \
# 0     8746     @handle Let's try and catch up live next week!
# 1     8746  Going to watch Grey's on the big screen - Thur...
# 2     8746  @handle My pleasure Patrick....hope you are well!
# 3     8746  @handle Hi there! Been traveling a lot and lot...
# 4     8746  RT @handle Looking to Drink Clean & Go Green? ...
# 5     8746  RT @handle: Ft. Hood officials confirm the 2 o...
# 6     8746  RT @handle: Mickey Mouse is Getting a Make Ove...
# 7     8746           @handle How did u get the invite Justin?
# 8     8746  @handle I think I am still a good friend of he...
# 9     8746  @handle I remember! I am fine - how are u? Wha...
# 10    8746     @handle That's great - good for the coach!!!!!
# 11    8746  @handle I don't want to picture u sitting on i...
# 12    8746  @handle D- Thanks for the RTs....are you going...
# 13    8746           @handle Grrr....you must be going crazy!
# 14    8746  @handle Hi there - just catching up from my tr...
# 15    8746  RT @handle: If you're looking for some great l...
# 16    8746  RT @handle: Retailers who aren’t engaging cust...
# 17    8746  RT @handle: Director of Global Brand Marketing...
# 18    8746  Still in car....want to jump out....45 minutes...
# 19    8746  RT @handle: "Only surround yourself with peopl...
# 20    8746  @handle wish I could but 24/7 w stu's family t...
# 21    8746  RT @handle: Help us help MusiCares! Vote for C...
# 22    8746                     @handle yum!!!! Save me some!!
# 23    8746  RT @handle: Gratitude is the sign of noble sou...
# 24    8746           @handle I don't think I know what it is!
# 25    8746  RT @handle: @handle Just found you via @handle...
# 26    8746  RT @handle: RT @handle: Travelling for the Hol...
# 27    8746       Just entering ohio - special hi to @handle!!
# 28    8746  @handle well we agree on one food thing friend...
# 29    8746                                @handle only 1!!!!!
# 30    8746               @handle only 4 more hours til Akron!
# 31    8746  @handle am driving to ohio...look fforward to ...
# 32    8746                   @handle just ate at the King!!!!
# 33    8746  RT @handle: Good read: Harvard Business - Opra...
# 34    8746  @handle u are a tough chick! Hope it did not r...
# 35    8746  @handle we let jake take one last week when he...
# 36    8746  @handle tennesee says hi back! Watching out fo...
# 37    8746  @handle ah hah....schools closed in atlanta to...
# 38    8746  @handle hi Lil! Driving thru tennessee now! Ar...
# 39    8746  RT @handle: Check it out- "12 Extremely Effect...
# 40    8746   @handle glad u remembered! Have a great holiday!
# 41    8746  RT @handle: More Thanksgiving leftover ideas h...
# 42    8746  @handle Thank you Rob - we are proud of the si...
# 43    8746  Night and Happy Thaksgiving to all my friends ...
# 44    8746  RT @handle: @handle Sounds amazing! Its going ...
# 45    8746                            @handle Tellme about it
# 46    8746  RT @handle: @handle Q12 Love the velvet jacket...
# 47    8746  RT @handle: Now I'm dreaming of new boots and ...
# 48    8746  RT @handle: RT @handle: Q12: WHAT ARE U MOST L...
# 49    8746                                    @handle LOL!!!!
# 50    8746  RT @handle: RT @handle: Become a fan of the fa...
# 51    8746  @handle It is a litt;e boring working from hom...
# 52    8746  RT @handle: Become a fan of the fashionable @h...
# 53    8746  !@handle Leaving at 6:00 am to drive to Akron ...
# 54    8746       @handle We have to compare notes! #anntaylor
# 55    8746  @handle Wish I had time to shop when I come - ...
# 56    8746  RT @handle: o my gosh i have fallen in love al...
# 57    8746      @handle Nice to see u here Andrew! #anntaylor
# 58    8746  RT @handle: @handle Q10- statement necklace, b...
# 59    8746  RT @handle: @handle @handle @handle @handle @h...
#
#                                                 words    URL  word_count  \
# 0   [handle, lets, try, and, catch, up, live, next...  False           9
# 1   [going, to, watch, greys, on, the, big, screen...  False          10
# 2   [handle, my, pleasure, patrickhope, you, are, ...  False           7
# 3   [handle, hi, there, been, traveling, a, lot, a...  False          25
# 4   [rt, handle, looking, to, drink, clean, go, gr...  False          18
# 5   [rt, handle, ft, hood, officials, confirm, the...  False          17
# 6   [rt, handle, mickey, mouse, is, getting, a, ma...   True          10
# 7     [handle, how, did, u, get, the, invite, justin]  False           8
# 8   [handle, i, think, i, am, still, a, good, frie...  False          12
# 9   [handle, i, remember, i, am, fine, how, are, u...  False          11
# 10      [handle, thats, great, good, for, the, coach]  False           7
# 11  [handle, i, dont, want, to, picture, u, sittin...  False          14
# 12  [handle, d, thanks, for, the, rtsare, you, goi...  False          11
# 13          [handle, grrryou, must, be, going, crazy]  False           6
# 14  [handle, hi, there, just, catching, up, from, ...  False          13
# 15  [rt, handle, if, youre, looking, for, some, gr...   True          15
# 16  [rt, handle, retailers, who, aren, ’, t, engag...   True          17
# 17  [rt, handle, director, of, global, brand, mark...   True          17
# 18  [still, in, carwant, to, jump, out45, minutes,...  False           8
# 19  [rt, handle, only, surround, yourself, with, p...  False          15
# 20  [handle, wish, i, could, but, 247, w, stus, fa...  False          22
# 21  [rt, handle, help, us, help, musicares, vote, ...   True          11
# 22                      [handle, yum, save, me, some]  False           5
# 23  [rt, handle, gratitude, is, the, sign, of, nob...  False          12
# 24    [handle, i, dont, think, i, know, what, it, is]  False           9
# 25  [rt, handle, handle, just, found, you, via, ha...  False          23
# 26  [rt, handle, rt, handle, travelling, for, the,...   True          18
# 27    [just, entering, ohio, special, hi, to, handle]  False           7
# 28  [handle, well, we, agree, on, one, food, thing...  False          19
# 29                                  [handle, only, 1]  False           3
# 30         [handle, only, 4, more, hours, til, akron]  False           7
# 31  [handle, am, driving, to, ohiolook, fforward, ...  False          12
# 32                 [handle, just, ate, at, the, king]  False           6
# 33  [rt, handle, good, read, harvard, business, op...   True          15
# 34  [handle, u, are, a, tough, chick, hope, it, di...  False          17
# 35  [handle, we, let, jake, take, one, last, week,...  False          17
# 36  [handle, tennesee, says, hi, back, watching, o...  False          17
# 37  [handle, ah, hahschools, closed, in, atlanta, ...  False          17
# 38  [handle, hi, lil, driving, thru, tennessee, no...  False          10
# 39  [rt, handle, check, it, out, 12, extremely, ef...   True          11
# 40  [handle, glad, u, remembered, have, a, great, ...  False           8
# 41  [rt, handle, more, thanksgiving, leftover, ideas]   True           6
# 42  [handle, thank, you, rob, we, are, proud, of, ...  False          12
# 43  [night, and, happy, thaksgiving, to, all, my, ...  False          16
# 44  [rt, handle, handle, sounds, amazing, its, goi...  False          18
# 45                        [handle, tellme, about, it]  False           4
# 46  [rt, handle, handle, q12, love, the, velvet, j...  False          19
# 47  [rt, handle, now, im, dreaming, of, new, boots...  False          17
# 48  [rt, handle, rt, handle, q12, what, are, u, mo...  False          18
# 49                                      [handle, lol]  False           2
# 50  [rt, handle, rt, handle, become, a, fan, of, t...   True          15
# 51  [handle, it, is, a, litte, boring, working, fr...  False          17
# 52  [rt, handle, become, a, fan, of, the, fashiona...   True          15
# 53  [handle, leaving, at, 600, am, to, drive, to, ...  False          16
# 54  [handle, we, have, to, compare, notes, anntaylor]  False           7
# 55  [handle, wish, i, had, time, to, shop, when, i...  False          20
# 56  [rt, handle, o, my, gosh, i, have, fallen, in,...  False          18
# 57  [handle, nice, to, see, u, here, andrew, annta...  False           8
# 58  [rt, handle, handle, q10, statement, necklace,...  False          10
# 59  [rt, handle, handle, handle, handle, handle, h...  False          15
#
#     sentence_length  text_length  sentiment  punctuation_per_tweet  \
# 0                35           46     0.0000               0.065217
# 1                49           66     0.0000               0.045455
# 2                37           49     0.7263               0.061224
# 3               100          132     0.4997               0.030303
# 4                86          109     0.4019               0.036697
# 5                86          105    -0.3400               0.028571
# 6                43           76     0.0000               0.052632
# 7                31           40     0.1531               0.050000
# 8                40           55     0.8478               0.054545
# 9                37           54     0.3510               0.092593
# 10               31           46     0.8469               0.086957
# 11               53           77     0.1996               0.051948
# 12               46           63     0.4404               0.063492
# 13               29           40    -0.4003               0.075000
# 14               50           68     0.0000               0.044118
# 15               63          105     0.6588               0.066667
# 16               82          117     0.0516               0.034188
# 17               86          135     0.5423               0.081481
# 18               35           53     0.0000               0.037736
# 19               81          101     0.0000               0.049505
# 20               77          107    -0.3400               0.065421
# 21               51           86     0.8172               0.058140
# 22               19           30     0.6562               0.066667
# 23               57           74     0.7430               0.067568
# 24               29           40     0.0000               0.075000
# 25               91          121     0.0000               0.041322
# 26               76          124     0.4574               0.048387
# 27               33           44     0.5080               0.068182
# 28               81          106     0.8777               0.056604
# 29               11           19     0.0000               0.105263
# 30               28           36     0.0000               0.055556
# 31               65           85     0.7959               0.035294
# 32               22           32     0.0000               0.062500
# 33               89          138     0.4404               0.043478
# 34               57           76     0.7232               0.026316
# 35               62           83     0.0000               0.036145
# 36               67           87     0.5475               0.034483
# 37               85          119     0.0000               0.025210
# 38               43           56     0.0000               0.035714
# 39               62          104     0.5256               0.057692
# 40               38           48     0.8856               0.041667
# 41               37           65     0.0000               0.061538
# 42               45           62     0.7633               0.048387
# 43               75           96     0.8999               0.031250
# 44               77          102     0.6580               0.039216
# 45               19           23     0.0000               0.043478
# 46               87          113     0.7959               0.053097
# 47               74           96     0.0000               0.052083
# 48               80          105     0.6176               0.038095
# 49                9           15     0.0000               0.133333
# 50               66          122     0.3802               0.049180
# 51               66           86    -0.2363               0.046512
# 52               63          117     0.5610               0.051282
# 53               70           89     0.4574               0.044944
# 54               35           44     0.0000               0.068182
# 55               72           96     0.5093               0.041667
# 56               74           95     0.4019               0.031579
# 57               35           45     0.4753               0.066667
# 58               55           73     0.0000               0.082192
# 59               68           92     0.9187               0.032609
#
#     unique_ratio  avg_word_length    mention  Retweet  \
# 0       1.000000         3.888889  {@handle}    False
# 1       1.000000         4.900000         {}    False
# 2       1.000000         5.285714  {@handle}    False
# 3       0.960000         4.000000  {@handle}    False
# 4       0.888889         4.777778  {@handle}     True
# 5       1.000000         5.058824  {@handle}     True
# 6       0.900000         4.300000  {@handle}     True
# 7       1.000000         3.875000  {@handle}    False
# 8       0.916667         3.333333  {@handle}    False
# 9       0.909091         3.363636  {@handle}    False
# 10      1.000000         4.428571  {@handle}    False
# 11      0.928571         3.785714  {@handle}    False
# 12      1.000000         4.181818  {@handle}     True
# 13      1.000000         4.833333  {@handle}    False
# 14      1.000000         3.846154  {@handle}    False
# 15      1.000000         4.200000  {@handle}     True
# 16      1.000000         4.823529  {@handle}     True
# 17      1.000000         5.058824  {@handle}     True
# 18      1.000000         4.375000         {}    False
# 19      1.000000         5.400000  {@handle}     True
# 20      1.000000         3.500000  {@handle}    False
# 21      0.909091         4.636364  {@handle}     True
# 22      1.000000         3.800000  {@handle}    False
# 23      0.916667         4.750000  {@handle}     True
# 24      0.888889         3.222222  {@handle}    False
# 25      0.869565         3.956522  {@handle}     True
# 26      0.888889         4.222222  {@handle}     True
# 27      1.000000         4.714286  {@handle}    False
# 28      1.000000         4.263158  {@handle}    False
# 29      1.000000         3.666667  {@handle}    False
# 30      1.000000         4.000000  {@handle}    False
# 31      0.916667         5.416667  {@handle}    False
# 32      1.000000         3.666667  {@handle}    False
# 33      0.866667         5.933333  {@handle}     True
# 34      0.941176         3.352941  {@handle}    False
# 35      1.000000         3.647059  {@handle}    False
# 36      1.000000         3.941176  {@handle}    False
# 37      1.000000         5.000000  {@handle}    False
# 38      1.000000         4.300000  {@handle}    False
# 39      1.000000         5.636364  {@handle}     True
# 40      1.000000         4.750000  {@handle}    False
# 41      1.000000         6.166667  {@handle}     True
# 42      1.000000         3.750000  {@handle}    False
# 43      0.937500         4.687500         {}    False
# 44      0.888889         4.277778  {@handle}     True
# 45      1.000000         4.750000  {@handle}    False
# 46      0.894737         4.578947  {@handle}     True
# 47      1.000000         4.352941  {@handle}     True
# 48      0.888889         4.444444  {@handle}     True
# 49      1.000000         4.500000  {@handle}    False
# 50      0.800000         4.400000  {@handle}     True
# 51      0.941176         3.882353  {@handle}    False
# 52      0.866667         4.200000  {@handle}     True
# 53      0.875000         4.375000         {}    False
# 54      1.000000         5.000000  {@handle}    False
# 55      0.950000         3.600000  {@handle}    False
# 56      1.000000         4.111111  {@handle}     True
# 57      1.000000         4.375000  {@handle}    False
# 58      0.900000         5.500000  {@handle}     True
# 59      0.600000         4.533333  {@handle}     True
#
#                               Hashtag emojis  profanity location
# 0                                  {}             False     None
# 1                                  {}             False     None
# 2                                  {}             False     None
# 3                                  {}             False     None
# 4                                  {}             False     None
# 5                                  {}             False     None
# 6                                  {}             False     None
# 7                                  {}             False     None
# 8                                  {}             False     None
# 9                                  {}             False     None
# 10                                 {}             False     None
# 11                                 {}             False     None
# 12                                 {}             False     None
# 13                                 {}             False     None
# 14                                 {}             False     None
# 15                                 {}             False     None
# 16                                 {}             False     None
# 17                 {#twitjobs, #jobs}             False     None
# 18                                 {}             False     None
# 19                     {#inspiration}             False     None
# 20                                 {}    Sad      False     None
# 21                                 {}             False     None
# 22                                 {}             False     None
# 23               {#gratitude, #quote}             False     None
# 24                                 {}             False     None
# 25                                 {}             False     None
# 26                                 {}             False     None
# 27                                 {}             False     ohio
# 28                    {#tweetsgiving}             False     None
# 29                                 {}             False     None
# 30                                 {}             False    Akron
# 31                                 {}             False     ohio
# 32                                 {}             False     None
# 33  {#leadership, #brand, #marketing}             False     None
# 34                                 {}             False     None
# 35                                 {}             False     None
# 36                                 {}             False     None
# 37                                 {}             False  atlanta
# 38                                 {}             False     None
# 39                                 {}             False     None
# 40                                 {}             False     None
# 41                                 {}             False     None
# 42                                 {}             False     None
# 43                       {#anntaylor}             False     None
# 44                 {#GNO, #anntaylor}             False      NYC
# 45                                 {}             False     None
# 46                 {#gno, #anntaylor}             False     None
# 47                 {#gno, #anntaylor}             False     None
# 48                 {#gno, #anntaylor}             False     None
# 49                                 {}             False     None
# 50                 {#gno, #anntaylor}             False     None
# 51                       {#anntaylor}             False     None
# 52                 {#gno, #anntaylor}             False     None
# 53                       {#anntaylor}             False    Akron
# 54                       {#anntaylor}             False     None
# 55                       {#anntaylor}             False      Atl
# 56            {#anntaylorstyle, #gno}             False     None
# 57                       {#anntaylor}             False     None
# 58                 {#gno, #anntaylor}             False     None
# 59                                 {}             False     None

# %%
import qgrid
qgrid_widget = qgrid.show_grid(train_data, show_toolbar=True)
qgrid_widget
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
save_pickle(train_data, os.path.join('train_data.p'))

# %%
df = train_data['Author'].unique()
print(len(df))
train_data.groupby('Author').count()
# Out:
# 9293
#         Tweet
# Author
# 2          17
# 3          11
# 4          18
# 6          39
# 7          37
# 8          34
# 9          55
# 10         86
# 11         19
# 12         40
# 13         51
# 14         33
# 15         38
# 16         45
# 17         55
# 18         37
# 19         34
# 20         18
# 21         39
# 22         16
# 23         18
# 24         86
# 25         54
# 26         35
# 27        101
# 28         81
# 30         20
# 31         17
# 34         37
# 35         20
# ...       ...
# 9968       38
# 9969       35
# 9970       33
# 9972       17
# 9973       55
# 9974       38
# 9975       54
# 9976       34
# 9977       16
# 9978       14
# 9979       37
# 9980       35
# 9981       34
# 9982       19
# 9983       19
# 9984       17
# 9986       17
# 9987       34
# 9988       53
# 9989       55
# 9990       17
# 9991       20
# 9992       36
# 9993       18
# 9995       18
# 9996       36
# 9997        6
# 9998       18
# 9999       18
# 10000      35
#
# [9293 rows x 1 columns]

# %%
clean_train.groupby(['Author'])['word_count'].describe()
# Out:
#         count       mean        std   min    25%   50%    75%    max
# Author
# 2        17.0  15.823529   5.468493   5.0  13.00  17.0  20.00   26.0
# 3        11.0  25.363636  33.950766   7.0  13.00  16.0  19.00  127.0
# 4        18.0  17.555556   3.275977  12.0  16.00  17.0  21.00   22.0
# 6        39.0  16.076923   6.558982   3.0  11.00  15.0  23.00   26.0
# 7        37.0  11.756757   7.251074   0.0   6.00  11.0  15.00   26.0
# 8        34.0   8.323529   2.760331   3.0   6.25   8.0  10.00   15.0
# 9        55.0  10.581818   6.172492   2.0   5.00   9.0  14.50   27.0
# 10       86.0  13.325581   6.984760   1.0   8.00  12.5  18.75   28.0
# 11       19.0   4.105263   2.579723   2.0   3.00   3.0   5.00   13.0
# 12       40.0  13.525000   5.546944   3.0   9.00  12.5  18.00   25.0
# 13       51.0   5.490196   6.821650   0.0   0.00   1.0  13.50   18.0
# 14       33.0  13.484848   6.856207   3.0   9.00  12.0  19.00   30.0
# 15       38.0  13.131579   7.162859   3.0   8.00  11.0  18.00   29.0
# 16       45.0  10.755556   4.057292   1.0   9.00  11.0  13.00   20.0
# 17       55.0  11.400000   4.844241   3.0   8.00  11.0  14.00   24.0
# 18       37.0  21.486486   3.237125  12.0  19.00  22.0  23.00   28.0
# 19       34.0  15.147059   7.257733   2.0  10.00  15.5  22.00   26.0
# 20       18.0  16.166667   6.128525   3.0  13.00  16.5  20.25   26.0
# 21       39.0  13.512821   4.827944   5.0  10.00  13.0  17.00   25.0
# 22       16.0  17.000000   7.302967   3.0  12.00  16.5  22.25   27.0
# 23       18.0  10.222222   5.297675   1.0   7.50  12.0  14.00   17.0
# 24       86.0  17.395349   5.893724   1.0  14.00  19.0  21.75   32.0
# 25       54.0   8.444444   4.483372   1.0   6.00   8.0  10.00   20.0
# 26       35.0  16.371429   2.509813  11.0  15.00  17.0  17.50   22.0
# 27      101.0  19.000000   5.424021   7.0  16.00  20.0  23.00   28.0
# 28       81.0  10.358025   5.334577   0.0   6.00  10.0  15.00   22.0
# 30       20.0   8.800000   6.329546   1.0   3.75   7.0  13.50   24.0
# 31       17.0  12.705882   6.430054   6.0   9.00  10.0  13.00   29.0
# 34       37.0  10.351351   5.197308   3.0   7.00   9.0  14.00   27.0
# 35       20.0  14.800000   4.007887   9.0  12.75  14.0  17.50   23.0
# ...       ...        ...        ...   ...    ...   ...    ...    ...
# 9968     38.0  24.710526   2.104152  20.0  24.00  24.5  26.00   29.0
# 9969     35.0  10.428571   6.175310   0.0   6.50   8.0  13.50   24.0
# 9970     33.0  19.545455   5.842147  10.0  15.00  20.0  25.00   30.0
# 9972     17.0   9.176471   6.346606   1.0   3.00   9.0  14.00   21.0
# 9973     55.0  11.109091   1.728548   9.0  10.00  10.0  13.00   14.0
# 9974     38.0  16.473684   1.032887  15.0  16.00  17.0  17.00   19.0
# 9975     54.0  19.055556   6.750029   3.0  14.25  19.0  24.75   31.0
# 9976     34.0  15.235294   0.955330  14.0  15.00  15.0  16.00   17.0
# 9977     16.0  18.062500   6.567280   6.0  13.25  19.5  24.00   27.0
# 9978     14.0  16.285714   5.075258  10.0  13.00  15.0  17.75   29.0
# 9979     37.0  12.621622   2.802294   5.0  11.00  12.0  14.00   19.0
# 9980     35.0  14.085714   6.284301   3.0   9.00  14.0  20.00   28.0
# 9981     34.0  11.647059   4.457764   2.0   9.00  11.0  14.50   21.0
# 9982     19.0  11.157895   4.462973   5.0   8.00  11.0  14.00   21.0
# 9983     19.0  15.842105   7.507501   4.0  11.50  18.0  20.50   30.0
# 9984     17.0  10.705882   6.536099   2.0   7.00  10.0  14.00   26.0
# 9986     17.0  10.176471   3.377042   3.0   8.00  10.0  12.00   16.0
# 9987     34.0  18.176471   3.128274  13.0  15.00  19.0  20.00   23.0
# 9988     53.0  19.018868   5.311419   4.0  16.00  20.0  23.00   27.0
# 9989     55.0  11.090909   7.045547   2.0   5.50   9.0  16.50   29.0
# 9990     17.0  14.411765   5.679556   3.0  10.00  15.0  19.00   23.0
# 9991     20.0  14.850000   6.815424   3.0  10.75  14.0  19.25   26.0
# 9992     36.0  13.277778   5.593931   4.0   9.00  13.0  17.00   27.0
# 9993     18.0  16.333333   5.313689   8.0  12.75  16.0  20.50   27.0
# 9995     18.0  10.388889   6.146629   1.0   6.00  10.5  13.75   23.0
# 9996     36.0  13.444444   4.170950   6.0  11.00  13.0  16.25   21.0
# 9997      6.0  18.666667   7.711463   7.0  14.25  19.5  24.75   27.0
# 9998     18.0  10.166667   5.711186   1.0   7.25  10.0  12.50   23.0
# 9999     18.0   7.666667   1.188177   6.0   7.00   7.5   8.75   10.0
# 10000    35.0  11.228571   6.462952   0.0   5.50  12.0  16.00   24.0
#
# [9293 rows x 8 columns]

# %%
feature_columns = ['Author', 'word_count', 'text_length', 'punctuation_per_tweet', 'unique_ratio', 'avg_word_length', 'sentiment']
df_features = train_data[feature_columns]
df_train=df_features.sample(frac=0.8,random_state=1)
df_dev=df_features.drop(df_train.index)

df_train.head()
# Out:
#         Author  word_count  text_length  punctuation_per_tweet  unique_ratio  \
# 271828    2779           5           34               0.029412        1.0000
# 283903    6970           3           16               0.062500        1.0000
# 66222     2016          16          108               0.027778        0.9375
# 82958     4535          14           68               0.058824        1.0000
# 105262    1614           6           37               0.027027        1.0000
#
#         avg_word_length  sentiment
# 271828         5.800000     0.4404
# 283903         4.333333     0.0000
# 66222          4.562500     0.4019
# 82958          3.642857     0.4019
# 105262         5.166667     0.0000

# %%
import tensorflow as tf

# continual numeric features
feature_word_count = tf.feature_column.numeric_column("word_count")
feature_text_length = tf.feature_column.numeric_column("text_length")
feature_punctuation_per_char = tf.feature_column.numeric_column("punctuation_per_tweet")
feature_unique_ratio = tf.feature_column.numeric_column("unique_ratio")
feature_avg_word_length = tf.feature_column.numeric_column("avg_word_length")
feature_sentiment = tf.feature_column.numeric_column("sentiment")

# if we just used the single top word we could do it this way (single-hot)
# feature_top_words = tf.feature_column.categorical_column_with_vocabulary_list(
#    "top_words", vocabulary_list=authors_top_words)

# feature_top_words = tf.feature_column.indicator_column(tf.feature_column.categorical_column_with_vocabulary_list(
#     "top_words_test", vocabulary_list=authors_top_words))

base_columns = [
    feature_word_count, feature_text_length, feature_punctuation_per_char, feature_unique_ratio, feature_avg_word_length, feature_sentiment
]

# %%
import tempfile

model_dir = tempfile.mkdtemp() # base temp directory for running models

# our Y value labels, i.e. the thing we are classifying
labels_train = df_train['Author'].astype(str)

# let's make a training function we can use with our estimators
train_fn = tf.estimator.inputs.pandas_input_fn(
    x=df_train,
    y=labels_train,
    batch_size=100,
    num_epochs=None, # unlimited
    shuffle=True, # shuffle the training data around
    num_threads=5)

# let's try a simple linear classifier
linear_model = tf.estimator.LinearClassifier(
    model_dir=model_dir, 
    feature_columns=base_columns,
    n_classes=9293,
    label_vocabulary= authors)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/2p/jbswxys17t7d4kttwhdtndm00000gn/T/tmps3fhz7wb', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1a82940ac8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
train_steps = 5000

# now let's train that model!
linear_model.train(input_fn=train_fn, steps=train_steps)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From /Users/wangyizhou/.local/lib/python3.6/site-packages/tensorflow/python/training/monitored_session.py:804: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 0 into /var/folders/2p/jbswxys17t7d4kttwhdtndm00000gn/T/tmps3fhz7wb/model.ckpt.
# INFO:tensorflow:loss = 913.70166, step = 1
# INFO:tensorflow:global_step/sec: 91.2036
# INFO:tensorflow:loss = 4031.8645, step = 101 (1.098 sec)
# INFO:tensorflow:global_step/sec: 84.1899
# INFO:tensorflow:loss = 3716.301, step = 201 (1.188 sec)
# INFO:tensorflow:global_step/sec: 88.4768
# INFO:tensorflow:loss = 3022.904, step = 301 (1.130 sec)
# INFO:tensorflow:global_step/sec: 88.9206
# INFO:tensorflow:loss = 3031.758, step = 401 (1.124 sec)
# INFO:tensorflow:global_step/sec: 88.4314
# INFO:tensorflow:loss = 2397.6096, step = 501 (1.131 sec)
# INFO:tensorflow:global_step/sec: 81.359
# INFO:tensorflow:loss = 2547.293, step = 601 (1.229 sec)
# INFO:tensorflow:global_step/sec: 81.7582
# INFO:tensorflow:loss = 2334.8977, step = 701 (1.223 sec)
# INFO:tensorflow:global_step/sec: 80.2434
# INFO:tensorflow:loss = 2150.8096, step = 801 (1.247 sec)
# INFO:tensorflow:global_step/sec: 88.7958
# INFO:tensorflow:loss = 2553.6748, step = 901 (1.126 sec)
# INFO:tensorflow:global_step/sec: 87.6566
# INFO:tensorflow:loss = 2256.2686, step = 1001 (1.140 sec)
# INFO:tensorflow:global_step/sec: 87.9662
# INFO:tensorflow:loss = 2067.6978, step = 1101 (1.137 sec)
# INFO:tensorflow:global_step/sec: 87.6034
# INFO:tensorflow:loss = 1687.6438, step = 1201 (1.141 sec)
# INFO:tensorflow:global_step/sec: 82.5475
# INFO:tensorflow:loss = 1843.5029, step = 1301 (1.212 sec)
# INFO:tensorflow:global_step/sec: 85.5175
# INFO:tensorflow:loss = 1730.2926, step = 1401 (1.169 sec)
# INFO:tensorflow:global_step/sec: 71.7836
# INFO:tensorflow:loss = 1668.3853, step = 1501 (1.393 sec)
# INFO:tensorflow:global_step/sec: 68.4666
# INFO:tensorflow:loss = 1866.3065, step = 1601 (1.460 sec)
# INFO:tensorflow:global_step/sec: 81.9749
# INFO:tensorflow:loss = 1670.9413, step = 1701 (1.220 sec)
# INFO:tensorflow:global_step/sec: 88.4632
# INFO:tensorflow:loss = 1515.2577, step = 1801 (1.130 sec)
# INFO:tensorflow:global_step/sec: 85.5614
# INFO:tensorflow:loss = 1276.6029, step = 1901 (1.169 sec)
# INFO:tensorflow:global_step/sec: 82.3084
# INFO:tensorflow:loss = 1434.0562, step = 2001 (1.215 sec)
# INFO:tensorflow:global_step/sec: 85.25
# INFO:tensorflow:loss = 1254.8105, step = 2101 (1.173 sec)
# INFO:tensorflow:global_step/sec: 89.856
# INFO:tensorflow:loss = 1540.4503, step = 2201 (1.113 sec)
# INFO:tensorflow:global_step/sec: 84.5453
# INFO:tensorflow:loss = 1245.499, step = 2301 (1.183 sec)
# INFO:tensorflow:global_step/sec: 84.4961
# INFO:tensorflow:loss = 1281.5851, step = 2401 (1.184 sec)
# INFO:tensorflow:global_step/sec: 84.0798
# INFO:tensorflow:loss = 1203.0587, step = 2501 (1.189 sec)
# INFO:tensorflow:global_step/sec: 88.4741
# INFO:tensorflow:loss = 1129.6636, step = 2601 (1.130 sec)
# INFO:tensorflow:global_step/sec: 89.7266
# INFO:tensorflow:loss = 1129.0126, step = 2701 (1.114 sec)
# INFO:tensorflow:global_step/sec: 89.4738
# INFO:tensorflow:loss = 1123.2611, step = 2801 (1.117 sec)
# INFO:tensorflow:global_step/sec: 90.1742
# INFO:tensorflow:loss = 1090.7072, step = 2901 (1.109 sec)
# INFO:tensorflow:global_step/sec: 91.2685
# INFO:tensorflow:loss = 1198.7881, step = 3001 (1.096 sec)
# INFO:tensorflow:global_step/sec: 85.5053
# INFO:tensorflow:loss = 1074.2739, step = 3101 (1.169 sec)
# INFO:tensorflow:global_step/sec: 77.0981
# INFO:tensorflow:loss = 1149.4653, step = 3201 (1.297 sec)
# INFO:tensorflow:global_step/sec: 79.8929
# INFO:tensorflow:loss = 1031.1699, step = 3301 (1.252 sec)
# INFO:tensorflow:global_step/sec: 82.5893
# INFO:tensorflow:loss = 1042.7566, step = 3401 (1.210 sec)
# INFO:tensorflow:global_step/sec: 88.2428
# INFO:tensorflow:loss = 1027.8611, step = 3501 (1.134 sec)
# INFO:tensorflow:global_step/sec: 70.7902
# INFO:tensorflow:loss = 1079.9594, step = 3601 (1.413 sec)
# INFO:tensorflow:global_step/sec: 81.8567
# INFO:tensorflow:loss = 1052.6849, step = 3701 (1.221 sec)
# INFO:tensorflow:global_step/sec: 86.5417
# INFO:tensorflow:loss = 944.5776, step = 3801 (1.155 sec)
# INFO:tensorflow:global_step/sec: 72.5298
# INFO:tensorflow:loss = 1014.1447, step = 3901 (1.379 sec)
# INFO:tensorflow:global_step/sec: 87.4917
# INFO:tensorflow:loss = 968.9926, step = 4001 (1.143 sec)
# INFO:tensorflow:global_step/sec: 87.0671
# INFO:tensorflow:loss = 974.6061, step = 4101 (1.148 sec)
# INFO:tensorflow:global_step/sec: 77.8251
# INFO:tensorflow:loss = 937.99396, step = 4201 (1.285 sec)
# INFO:tensorflow:global_step/sec: 76.178
# INFO:tensorflow:loss = 944.7692, step = 4301 (1.313 sec)
# INFO:tensorflow:global_step/sec: 83.2752
# INFO:tensorflow:loss = 987.0268, step = 4401 (1.200 sec)
# INFO:tensorflow:global_step/sec: 80.4585
# INFO:tensorflow:loss = 985.4275, step = 4501 (1.243 sec)
# INFO:tensorflow:global_step/sec: 85.2311
# INFO:tensorflow:loss = 964.3316, step = 4601 (1.173 sec)
# INFO:tensorflow:global_step/sec: 86.1373
# INFO:tensorflow:loss = 917.1141, step = 4701 (1.161 sec)
# INFO:tensorflow:global_step/sec: 84.5392
# INFO:tensorflow:loss = 952.55615, step = 4801 (1.183 sec)
# INFO:tensorflow:global_step/sec: 84.7736
# INFO:tensorflow:loss = 924.7418, step = 4901 (1.179 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into /var/folders/2p/jbswxys17t7d4kttwhdtndm00000gn/T/tmps3fhz7wb/model.ckpt.
# INFO:tensorflow:Loss for final step: 963.93097.

# %%
authors = train_data.Author.unique().tolist()
authors = list(map(str, authors))
# Out:
# ['2779', '6970', '2016', '4535', '1614', '6362', '946', '9066', '1200', '8075', '612', '9916', '4462', '4253', '5659', '7232', '9558', '1613', '6203', '3666', '274', '5238', '4598', '7796', '5293', '9543', '5682', '966', '7086', '7442', '3033', '519', '2273', '9396', '1159', '4578', '7953', '2335', '8931', '5393', '4922', '1526', '300', '8289', '7468', '1594', '9684', '5197', '2002', '8526', '1317', '6986', '8440', '2797', '9437', '6492', '1334', '568', '8213', '1125', '8738', '6650', '5163', '9249', '9176', '6858', '7693', '6317', '9145', '9338', '5561', '3392', '281', '8137', '5588', '1889', '9961', '580', '1340', '8193', '3021', '6794', '7320', '7466', '3869', '6257', '4850', '2261', '9645', '8005', '9769', '7717', '6224', '6734', '6063', '7932', '3747', '5461', '3752', '1412', '5770', '6107', '1587', '2309', '7841', '6136', '5424', '181', '2213', '1342', '4261', '1080', '3936', '2461', '2698', '989', '5613', '6579', '1032', '8539', '1198', '9218', '408', '1255', '2638', '6466', '4928', '3842', '6330', '872', '5004', '7304', '7372', '1371', '3708', '5519', '6700', '5485', '725', '5155', '4537', '8874', '4565', '7525', '9628', '9565', '5357', '2014', '8229', '298', '8259', '7665', '256', '171', '8485', '9185', '6424', '565', '7847', '5805', '5006', '6596', '6632', '9259', '4064', '314', '2727', '6085', '4486', '2556', '7100', '3', '6017', '249', '6937', '8496', '9251', '1743', '7913', '4919', '5264', '8746', '4263', '5102', '7730', '513', '7853', '2532', '8976', '2764', '451', '8014', '1267', '9342', '4398', '4578', '193', '841', '4139', '9926', '6648', '1961', '8849', '2217', '5557', '9442', '5912', '5664', '5698', '9196', '478', '487', '8951', '7487', '756', '1206', '4682', '396', '4487', '2470', '3114', '6162', '7388', '5155', '4970', '1020', '6580', '3216', '2484', '4110', '4778', '7181', '415', '898', '1470', '5205', '3563', '9271', '1854', '8625', '1473', '1883', '3624', '9331', '6302', '6650', '5518', '6230', '5091', '4866', '6280', '7929', '7616', '1661', '764', '1382', '7906', '7339', '8405', '9685', '7917', '4798', '1009', '3724', '7524', '5796', '1626', '7818', '4267', '2316', '8841', '6455', '1615', '1146', '4640', '5341', '5128', '7802', '644', '4776', '246', '6429', '3578', '2456', '9529', '8086', '6070', '9135', '2738', '6128', '9914', '3821', '1676', '325', '8905', '8144', '4949', '9806', '7513', '9322', '4726', '9220', '4936', '8819', '9756', '6114', '699', '8', '8779', '6517', '9410', '8439', '9482', '5654', '782', '4363', '8432', '1273', '5594', '7721', '6442', '2777', '2299', '6767', '2827', '8094', '1933', '3492', '9437', '2241', '7216', '3706', '4785', '9663', '8027', '5573', '2304', '9645', '161', '7738', '2214', '206', '9911', '1610', '360', '8195', '1434', '9011', '5004', '8561', '1418', '7986', '3907', '3678', '3461', '8846', '5693', '8975', '8961', '2183', '7530', '8486', '7305', '2647', '2086', '9628', '547', '7936', '1158', '257', '9329', '2594', '9920', '3009', '6743', '9067', '2105', '8507', '1726', '1668', '8707', '5140', '1030', '3828', '4952', '1524', '4960', '7237', '6238', '7134', '3327', '2017', '3989', '3059', '1113', '4649', '5437', '7269', '1482', '4554', '7768', '6940', '7171', '6040', '6', '2248', '764', '2432', '8839', '2832', '1466', '963', '6122', '1788', '2812', '9219', '2494', '355', '7075', '2481', '7204', '2358', '5716', '1384', '438', '2271', '8875', '1011', '1677', '4640', '3956', '6520', '1017', '4998', '6237', '9207', '5022', '8118', '9575', '2104', '8710', '373', '5938', '9543', '8107', '5635', '3087', '7035', '193', '4565', '6460', '5601', '974', '2405', '9174', '1484', '7823', '3416', '9718', '12', '1836', '2325', '81', '3006', '4054', '8800', '3566', '5704', '2522', '2715', '1171', '9806', '1312', '9689', '9496', '8687', '9788', '6668', '7661', '228', '3908', '9911', '9327', '8299', '6272', '8141', '1707', '7017', '8735', '9374', '9682', '9419', '8720', '7708', '267', '8708', '8558', '7513', '6278', '1150', '5619', '6033', '5288', '8579', '3450', '1671', '6455', '7310' ...

# %%
print
# Out:
# 271828    2779
# 283903    6970
# 66222     2016
# 82958     4535
# 105262    1614
# 128776    6362
# 265964     946
# 146866    9066
# 60946     1200
# 175159    8075
# 245539     612
# 131689    9916
# 230051    4462
# 268456    4253
# 91792     5659
# 202557    7232
# 321222    9558
# 254326    1613
# 62053     6203
# 210410    3666
# 129081     274
# 222739    5238
# 278044    4598
# 47349     7796
# 192297    5293
# 114101    9543
# 295026    5682
# 322966     966
# 50602     7086
# 160855    7442
#           ...
# 162771    3118
# 54790     7887
# 211248    1034
# 55646     5086
# 186061    3356
# 71384     9759
# 170702    1896
# 205685    9359
# 196465    5517
# 97189     4748
# 277360    4988
# 10698     6871
# 5768      9556
# 114463    5968
# 216011    8498
# 125686    9063
# 115519    7663
# 171420    7776
# 124897    3672
# 57207     3234
# 59351      271
# 70430     2785
# 203047    9868
# 220201    8192
# 86341     8878
# 37943     1395
# 37130     4317
# 253130    2370
# 23474     4240
# 220781    8616
# Name: Author, Length: 262556, dtype: int64

# %%
dev_test_fn = tf.estimator.inputs.pandas_input_fn(
    x=df_dev,
    y=df_dev['Author'].astype(str),
    batch_size=100,
    num_epochs=1, # just one run
    shuffle=False, # don't shuffle test here
    num_threads=5)

linear_model.evaluate(input_fn=dev_test_fn)["accuracy"]
# Out:
# WARNING:tensorflow:enqueue_data was called with num_epochs and num_threads > 1. num_epochs is applied per thread, so this will produce more epochs than you probably intend. If you want to limit epochs, use one thread.
# WARNING:tensorflow:enqueue_data was called with shuffle=False and num_threads > 1. This will create multiple threads, all reading the array/dataframe in order. If you want examples read in order, use one thread; if you want multiple threads, enable shuffling.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-08-25-02:49:28
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/2p/jbswxys17t7d4kttwhdtndm00000gn/T/tmps3fhz7wb/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-08-25-02:50:02
# INFO:tensorflow:Saving dict for global step 5000: accuracy = 0.00067033316, average_loss = 9.5999775, global_step = 5000, loss = 959.9831
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: /var/folders/2p/jbswxys17t7d4kttwhdtndm00000gn/T/tmps3fhz7wb/model.ckpt-5000
# 0.00067033316

# %%
# Out:
#   File "<ipython-input-44-43bc7b85caf5>", line 1
#     >python -m spacy download en_core_web_lg
#     ^
# SyntaxError: invalid syntax

# %%
# Out:
#   File "<ipython-input-46-649578a24256>", line 1
#     spacy download en_core_web_lg
#                  ^
# SyntaxError: invalid syntax
